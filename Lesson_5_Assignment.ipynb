# %% [markdown]
# Name: **Stephane Chambrelain Talla Fotsing**
# Student Number: **ST139766**
# Program: **Data Analytics and Artificial Intelligence**
# Course - **Introduction to Artificial Intelligence**
# **Assignment 5: Exploratory Data Analysis with Pandas**

# %% [markdown]
# **Assignment - EDA using Pandas**
#
# ***Instructions***
# - Clone a copy of the assignment notebook in Google Colab.
# - **Complete the tasks by filling in the code where indicated by TODO comments. Put each task in a new cell.**
# - Run each cell to ensure your code works correctly.
# - Pay attention to the output of each cell and interpret the results.
# - For visualisation tasks, make sure to label axes, add titles, and choose appropriate colour schemes.
# - After completing all tasks, review your findings and include notes of your insights gained from the EDA process as markdown notes for assessments.

# %% [markdown]
# # Titanic Dataset Exploratory Data Analysis

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Task 1: Load the Titanic dataset

# %%
# TODO: Load the Titanic dataset from the following URL
# url = "https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv"
df = pd.read_csv("Titanic-Dataset.csv")

# %% [markdown]
# # Task 2: Inspect the data

# %%
# TODO: Display the first 5 rows of the dataset
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# TODO: Display the last 5 rows of the dataset
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# TODO: Display the data types of each column
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# TODO: Display summary statistics of the numerical columns
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Task 3: Clean and preprocess the data

# %%
# TODO: Create a new categorical feature 'PclassCategory' from 'Pclass'
df['PclassCategory'] = df['Pclass'].astype('category')

# %%
# TODO: Create a new categorical feature 'CabinCategory' from 'Cabin'
df['CabinCategory'] = df['Cabin'].astype('category')

# %%
# TODO: Handle missing values in the 'Age' column (use mean age)
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
# TODO: Create a 'Family' feature by combining 'SibSp' and 'Parch'
df['Family'] = df['SibSp'] + df['Parch']

# %% [markdown]
# # Task 4: Identify specific data points

# %%
# TODO: Find passengers with the highest fare
highest_fare_passengers = df.nlargest(1, 'Fare', keep='all')

# %%
# TODO: Find passengers with the largest family size
largest_family_passengers = df.nlargest(1, 'Family', keep='all')

# %% [markdown]
# # Task 5: Demonstrate Pandas Series and DataFrame functionalities

# %%
# TODO: Create a Pandas Series of passenger names
names_series = df['Name']
names_series.head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
# TODO: Create a DataFrame of passenger names and ages
names_ages_df =  df[['Name', 'Age']].copy()
names_ages_df.head()
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
# TODO: Slice the DataFrame to show only passengers older than 50
older_passengers = df[df['Age'] > 50]
older_passengers.head()
# Out:
#     PassengerId  Survived  Pclass                              Name     Sex  \
# 6             7         0       1           McCarthy, Mr. Timothy J    male
# 11           12         1       1          Bonnell, Miss. Elizabeth  female
# 15           16         1       2  Hewlett, Mrs. (Mary D Kingcome)   female
# 33           34         0       2             Wheadon, Mr. Edward H    male
# 54           55         0       1    Ostby, Mr. Engelhart Cornelius    male
#
#      Age  SibSp  Parch      Ticket     Fare Cabin Embarked PclassCategory  \
# 6   54.0      0      0       17463  51.8625   E46        S              1
# 11  58.0      0      0      113783  26.5500  C103        S              1
# 15  55.0      0      0      248706  16.0000   NaN        S              2
# 33  66.0      0      0  C.A. 24579  10.5000   NaN        S              2
# 54  65.0      0      1      113509  61.9792   B30        C              1
#
#    CabinCategory
# 6            E46
# 11          C103
# 15           NaN
# 33           NaN
# 54           B30

# %% [markdown]
# # Task 6: Introduce multi-indexing

# %%
# TODO: Create a multi-index DataFrame grouped by 'Sex' and 'Pclass'
multi_index_df =  df.groupby(['Sex', 'Pclass']).mean(numeric_only=True)
multi_index_df.head()
# Out:
#                PassengerId  Survived        Age     SibSp     Parch  \
# Sex    Pclass
# female 1        469.212766  0.968085  34.611765  0.553191  0.457447
#        2        443.105263  0.921053  28.722973  0.486842  0.605263
#        3        399.729167  0.500000  21.750000  0.895833  0.798611
# male   1        455.729508  0.368852  41.281386  0.311475  0.278689
#        2        447.962963  0.157407  30.740707  0.342593  0.222222
#
#                      Fare
# Sex    Pclass
# female 1       106.125798
#        2        21.970121
#        3        16.118810
# male   1        67.226127
#        2        19.741782

# %% [markdown]
# # Task 7: Visualizations

# %%
# TODO: Create a histogram of passenger ages
plt.figure(figsize=(10, 6))
# Create the histogram using the 'Age' column
plt.hist(df['Age'], bins=20, edgecolor='black', color='skyblue')
plt.title('Histogram of Passenger Ages')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# TODO: Create a bar plot of survival rates by passenger class
# Calculate the survival rate (mean of 'Survived') for each passenger class
survival_rates = df.groupby('Pclass')['Survived'].mean()

# Plot the data as a bar chart
plt.figure(figsize=(8, 5))
survival_rates.plot(kind='bar', color=['crimson', 'orange', 'gold', 'teal'][:len(survival_rates)], edgecolor='black')

# Add titles and labels
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Passenger Class (Pclass)')
plt.ylabel('Survival Rate (0.0 - 1.0)')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# TODO: Create a heatmap of correlation between numerical features
plt.figure(figsize=(12, 10))

# Compute the correlation matrix for numerical features only
corr_matrix = df.corr(numeric_only=True)

# Generate the heatmap using seaborn
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %%
# TODO: Create a pair plot of 'Age', 'Fare', 'SibSp', and 'Parch', colored by 'Survived'
# Create the pair plot for specified columns, with color determined by 'Survived'
sns.pairplot(data=df, vars=['Age', 'Fare', 'SibSp', 'Parch'], hue='Survived', palette='bright', diag_kind='kde')
# Display the visualization
plt.show()

# %% [markdown]
# # Task 8: Analyze survival rates

# %%
# TODO: Calculate and display survival rates by sex
survival_by_sex = df.groupby('Sex')['Survived'].mean()
survival_by_sex * 100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
# TODO: Calculate and display survival rates by passenger class
survival_by_class = df.groupby('Pclass')['Survived'].mean()
survival_by_class * 100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %% [markdown]
# # Task 9: Analyze age distribution

# %%
# TODO: Create a box plot of age distribution by passenger class and sex
plt.figure(figsize=(12, 6))
# Create the box plot using passenger class on the x-axis, age on the y-axis, and sex as the hue color
sns.boxplot(data=df, x='Pclass', y='Age', hue='Sex', palette='Set2')
plt.title('Age Distribution by Passenger Class and Sex')
plt.xlabel('Passenger Class (Pclass)')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# # Task 10: Analyze fare distribution

# %%
# TODO: Create a violin plot of fare distribution by passenger class and survival status
plt.figure(figsize=(12, 6))

# Create the violin plot
sns.violinplot(data=df, x='Pclass', y='Fare', hue='Survived', split=True, palette='muted')

plt.title('Fare Distribution by Passenger Class and Survival Status')
plt.xlabel('Passenger Class (Pclass)')
plt.ylabel('Fare')
plt.ylim(0, 300)
plt.show()

print("EDA tasks completed.")
# Out:
# EDA tasks completed.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from getpass import getpass
github_token = getpass("Enter your GitHub PAT: ")
# Out:
# Enter your GitHub PAT: ··········

# %%
# !git config --global user.name "StephaneTF"
# !git config --global user.email "39239463+StephaneTF@users.noreply.github.com"

# %%
# !git config --global user.name
# !git config --global user.email
# Out:
# StephaneTF
# 39239463+StephaneTF@users.noreply.github.com

# %%
# !git clone -q https://$github_token@github.com/StephaneTF/colab-git-assignment2-ST.git /content/colab-git-assignment2-ST

# %%
# !ls -la /content/colab-git-assignment2-ST
# Out:
# total 116
# drwxr-xr-x 3 root root  4096 Sep  8 01:01  .
# drwxr-xr-x 1 root root  4096 Sep  8 01:01  ..
# -rw-r--r-- 1 root root  5415 Sep  8 01:01  assignment2.ipynb
# drwxr-xr-x 8 root root  4096 Sep  8 01:01  .git
# -rw-r--r-- 1 root root 12704 Sep  8 01:01  Lesson_3_assignment.ipynb
# -rw-r--r-- 1 root root 80271 Sep  8 01:01 'Lesson 4 assignment.ipynb'

# %%
# !find "/content/drive/MyDrive" -name "Lesson_5*"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Lesson_5_Assignment.ipynb

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Lesson_5_assignment.ipynb" \
"/c
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab Notebooks/Lesson_5_assignment.ipynb': No such file or directory
