# %% [markdown]
# Name: **Stephane Chambrelain Talla Fotsing**
# Student Number: **ST139766**
# Program: **Data Analytics and Artificial Intelligence**
# Course - **Introduction to Artificial Intelligence**
# **Assignment 3: Python Refresher**

# %% [markdown]
# #### **ATTENTION!!!**
# - **Place each section (1,2...) in one or more cells to keep the notebook organised**
# - **Complete the codes in the `TODO` sections**

# %%
# Python Library Management System

# Install required libraries (This should already exist in colab)
# !pip install requests

import pickle
import sqlite3
import requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests) (2026.7.22)

# %%
# 1. Data Types and Variables
book_title = "Python Programming"
book_quantity = 5
book_price = 29.99
is_available = True

print(f"Book: {book_title}, Quantity: {book_quantity}, Price: ${book_price}, Available: {is_available}")
# Out:
# Book: Python Programming, Quantity: 5, Price: $29.99, Available: True

# %%
# 2. Lists
books = ["Python Basics", "Advanced Python", "Data Science with Python"]

# TODO: Add two more books to the list
books.append("Machine Learning")
books.insert(1, "SQL Databases")

print("Updated book list:", books)
# Out:
# Updated book list: ['Python Basics', 'SQL Databases', 'Advanced Python', 'Data Science with Python', 'Machine Learning']

# %%
# 3. Loops and range()
print("\nAvailable books:")
# TODO: Use a for loop and range() to print books with their indices
for index in range(len(books)):
      print(index, books[index])
# Out:
# Available books:
# 0 Python Basics
# 1 SQL Databases
# 2 Advanced Python
# 3 Data Science with Python
# 4 Machine Learning

# %%
# 4. User Input
new_book = input("Enter a new book title: ")
books.append(new_book)
print("Updated book list:", books)
# Out:
# Enter a new book title: Deep Learning
# Updated book list: ['Python Basics', 'SQL Databases', 'Advanced Python', 'Data Science with Python', 'Machine Learning', 'Deep Learning']

# %%
# 5. Functions and Conditional Statements
def check_availability(book_name):
    # TODO: Check if the book is in the list and return True if available, False otherwise
    if book_name in books:
      return True
    else:
      return False
    pass

# Test the function
print(f"Is 'Python Basics' available? {check_availability('Python Basics')}")
# Out:
# Is 'Python Basics' available? True

# %%
# 6. File I/O
def save_books_to_file(filename):
    with open(filename, 'w') as f:
        for book in books:
            f.write(f"{book}\n")

# TODO: Implement a function to read books from a file
def read_books_from_file(filename):
    with open(filename, 'r') as f:
        books_from_file = []

        for line in f:
            books_from_file.append(line.strip())

        return books_from_file

# Test file I/O
save_books_to_file("books.txt")
# !cat books.txt  # Display file contents in Colab
# Out:
# Python Basics
# SQL Databases
# Advanced Python
# Data Science with Python
# Machine Learning
# Deep Learning

# %%
# 7. Pickle for serialization
def save_books_pickle(filename):
    with open(filename, 'wb') as f:
        pickle.dump(books, f)

# TODO: Implement a function to load books using pickle
def load_books_pickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# Test pickle functions
save_books_pickle("books.pkl")
# Uncomment the next line after implementing load_books_pickle
print("Books loaded from pickle:", load_books_pickle("books.pkl"))
# Out:
# Books loaded from pickle: ['Python Basics', 'SQL Databases', 'Advanced Python', 'Data Science with Python', 'Machine Learning', 'Deep Learning']

# %%
# 8. SQLite Database Interaction
def create_books_table():
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()
    cursor.execute('''CREATE TABLE IF NOT EXISTS books
                      (id INTEGER PRIMARY KEY, title TEXT, quantity INTEGER)''')
    conn.commit()
    conn.close()

# TODO: Implement a function to add a book to the SQLite database
def add_book_to_db(title, quantity):
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()

    cursor.execute("INSERT INTO books (title, quantity) VALUES (?, ?)", (title, quantity))

    conn.commit()
    conn.close()

# Test database functions
create_books_table()
# Uncomment the next line after implementing add_book_to_db
add_book_to_db("Python for Beginners", 10)

# %%
# 9. Web API Interaction (GitHub API)
def get_python_repos():
    url = "https://api.github.com/search/repositories"
    params = {"q": "language:python", "sort": "stars", "order": "desc"}
    response = requests.get(url, params=params)
    data = response.json()
    return [repo['name'] for repo in data['items'][:5]]

# Test API function
print("Top 5 Python repositories on GitHub:", get_python_repos())

print("\nLibrary Management System operations completed.")
# Out:
# Top 5 Python repositories on GitHub: ['public-apis', 'free-programming-books', 'system-design-primer', 'awesome-python', 'project-based-learning']
#
# Library Management System operations completed.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive/MyDrive -name "Lesson_3_assignment.ipynb"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Lesson_3_assignment.ipynb

# %%
# %cd /content
# !git clone https://github.com/StephaneTF/colab-git-assignment2-ST.git
# Out:
# /content
# Cloning into 'colab-git-assignment2-ST'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 1), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 4.06 KiB | 4.06 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# !ls -la /content/colab-git-assignment2-ST
# Out:
# total 20
# drwxr-xr-x 3 root root 4096 Sep  4 02:40 .
# drwxr-xr-x 1 root root 4096 Sep  4 02:40 ..
# -rw-r--r-- 1 root root 5415 Sep  4 02:40 assignment2.ipynb
# drwxr-xr-x 8 root root 4096 Sep  4 02:40 .git
