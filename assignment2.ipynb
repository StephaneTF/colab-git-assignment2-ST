# %% [markdown]
# Name: **Stephane Chambrelain Talla Fotsing**
# Student Number: **ST139766**
# Program: **Data Analytics and Artificial Intelligence**
# Course - **Introduction to Artificial Intelligence**
# **Assignment 2: Git and GitHub Version Control**

# %% [markdown]
# ## 2. Google Colab Environment

# %%
# !git config --global user.email "stephanetalla.f@gmail.com"
# !git config --global user.name "StephaneTF"

# %%
# !git --version
# Out:
# git version 2.34.1

# %%
# !git config --global user.email
# !git config --global user.name
# Out:
# stephanetalla.f@gmail.com
# StephaneTF

# %% [markdown]
# ## 3. Repository Setup

# %%
# !git clone https://github.com/StephaneTF/colab-git-assignment2-ST.git
# Out:
# Cloning into 'colab-git-assignment2-ST'...
# ...

# %%
# !ls
# Out:
# colab-git-assignment2-ST  sample_data

# %%
# !ls -la colab-git-assignment2-ST
# Out:
# total 12
# drwxr-xr-x 3 root root 4096 Sep  3 07:10 .
# drwxr-xr-x 1 root root 4096 Sep  3 07:10 ..
# drwxr-xr-x 7 root root 4096 Sep  3 07:10 .git

# %% [markdown]
# ## 4. Notebook Creation

# %% [markdown]
# # Git and GitHub Assignment 2
# This notebook demonstrates basic Git operations.

# %%
def multiply_numbers(a, b):
    return a * b
print(multiply_numbers(3, 4))
# Out:
# 12

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive/MyDrive -name "assignment2.ipynb"
# Out:
# /content/drive/MyDrive/Colab Notebooks/assignment2.ipynb
